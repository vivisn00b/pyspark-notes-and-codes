# %%
# Spark Session

from pyspark.sql import SparkSession

spark = (
    SparkSession
    .builder
    .appName("Basic Transformation - II")
    .master("local[*]")
    .getOrCreate()
)

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://7cd61605f34d:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Basic Transformation - II</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# Emp Data & Schema

emp_data = [
    ["001","101","John Doe","30","Male","50000","2015-01-01"],
    ["002","101","Jane Smith","25","Female","45000","2016-02-15"],
    ["003","102","Bob Brown","35","Male","55000","2014-05-01"],
    ["004","102","Alice Lee","28","Female","48000","2017-09-30"],
    ["005","103","Jack Chan","40","Male","60000","2013-04-01"],
    ["006","103","Jill Wong","32","Female","52000","2018-07-01"],
    ["007","101","James Johnson","42","Male","70000","2012-03-15"],
    ["008","102","Kate Kim","29","Female","51000","2019-10-01"],
    ["009","103","Tom Tan","33","Male","58000","2016-06-01"],
    ["010","104","Lisa Lee","27","Female","47000","2018-08-01"],
    ["011","104","David Park","38","Male","65000","2015-11-01"],
    ["012","105","Susan Chen","31","Female","54000","2017-02-15"],
    ["013","106","Brian Kim","45","Male","75000","2011-07-01"],
    ["014","107","Emily Lee","26","Female","46000","2019-01-01"],
    ["015","106","Michael Lee","37","Male","63000","2014-09-30"],
    ["016","107","Kelly Zhang","30","Female","49000","2018-04-01"],
    ["017","105","George Wang","34","Male","57000","2016-03-15"],
    ["018","104","Nancy Liu","29","Female","50000","2017-06-01"],
    ["019","103","Steven Chen","36","Male","62000","2015-08-01"],
    ["020","102","Grace Kim","32","Female","53000","2018-11-01"]
]

emp_schema = "employee_id string, department_id string, name string, age string, gender string, salary string, hire_date string"

# %%
# Create emp DataFrame

emp = spark.createDataFrame(data=emp_data, schema=emp_schema)

# %%
# Show emp dataframe (ACTION)

emp.show()
# Out:
# +-----------+-------------+-------------+---+------+------+----------+
# |employee_id|department_id|         name|age|gender|salary| hire_date|
# +-----------+-------------+-------------+---+------+------+----------+
# |        001|          101|     John Doe| 30|  Male| 50000|2015-01-01|
# |        002|          101|   Jane Smith| 25|Female| 45000|2016-02-15|
# |        003|          102|    Bob Brown| 35|  Male| 55000|2014-05-01|
# |        004|          102|    Alice Lee| 28|Female| 48000|2017-09-30|
# |        005|          103|    Jack Chan| 40|  Male| 60000|2013-04-01|
# |        006|          103|    Jill Wong| 32|Female| 52000|2018-07-01|
# |        007|          101|James Johnson| 42|  Male| 70000|2012-03-15|
# |        008|          102|     Kate Kim| 29|Female| 51000|2019-10-01|
# |        009|          103|      Tom Tan| 33|  Male| 58000|2016-06-01|
# |        010|          104|     Lisa Lee| 27|Female| 47000|2018-08-01|
# |        011|          104|   David Park| 38|  Male| 65000|2015-11-01|
# |        012|          105|   Susan Chen| 31|Female| 54000|2017-02-15|
# |        013|          106|    Brian Kim| 45|  Male| 75000|2011-07-01|
# |        014|          107|    Emily Lee| 26|Female| 46000|2019-01-01|
# |        015|          106|  Michael Lee| 37|  Male| 63000|2014-09-30|
# |        016|          107|  Kelly Zhang| 30|Female| 49000|2018-04-01|
# |        017|          105|  George Wang| 34|  Male| 57000|2016-03-15|
# |        018|          104|    Nancy Liu| 29|Female| 50000|2017-06-01|
# |        019|          103|  Steven Chen| 36|  Male| 62000|2015-08-01|
# |        020|          102|    Grace Kim| 32|Female| 53000|2018-11-01|
# +-----------+-------------+-------------+---+------+------+----------+

# %%
# Print Schema

emp.printSchema()
# Out:
# root
#  |-- employee_id: string (nullable = true)
#  |-- department_id: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- age: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- salary: string (nullable = true)
#  |-- hire_date: string (nullable = true)

# %%
# Casting Column
# select employee_id, name, age, cast(salary as double) as salary from emp

from pyspark.sql.functions import cast, col

emp_casted = emp.select("employee_id", "name", col("age").cast("int"), col("salary").cast("double"))

# %%
emp_casted.printSchema()
# Out:
# root
#  |-- employee_id: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- salary: double (nullable = true)

# %%
# Adding Columns
# select employee_id, name, age, (salary * 0.2), hire_date from emp_casted

emp_taxed = emp.select("employee_id", "name", col("salary") * 0.2, col("hire_date").cast("date"))

# %%
emp_taxed.printSchema()
emp_taxed.show()
# Out:
# root
#  |-- employee_id: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- (salary * 0.2): double (nullable = true)
#  |-- hire_date: date (nullable = true)
#
# +-----------+-------------+--------------+----------+
# |employee_id|         name|(salary * 0.2)| hire_date|
# +-----------+-------------+--------------+----------+
# |        001|     John Doe|       10000.0|2015-01-01|
# |        002|   Jane Smith|        9000.0|2016-02-15|
# |        003|    Bob Brown|       11000.0|2014-05-01|
# |        004|    Alice Lee|        9600.0|2017-09-30|
# |        005|    Jack Chan|       12000.0|2013-04-01|
# |        006|    Jill Wong|       10400.0|2018-07-01|
# |        007|James Johnson|       14000.0|2012-03-15|
# |        008|     Kate Kim|       10200.0|2019-10-01|
# |        009|      Tom Tan|       11600.0|2016-06-01|
# |        010|     Lisa Lee|        9400.0|2018-08-01|
# |        011|   David Park|       13000.0|2015-11-01|
# |        012|   Susan Chen|       10800.0|2017-02-15|
# |        013|    Brian Kim|       15000.0|2011-07-01|
# |        014|    Emily Lee|        9200.0|2019-01-01|
# |        015|  Michael Lee|       12600.0|2014-09-30|
# |        016|  Kelly Zhang|        9800.0|2018-04-01|
# |        017|  George Wang|       11400.0|2016-03-15|
# |        018|    Nancy Liu|       10000.0|2017-06-01|
# |        019|  Steven Chen|       12400.0|2015-08-01|
# |        020|    Grace Kim|       10600.0|2018-11-01|
# +-----------+-------------+--------------+----------+

# %%
# select employee_id, name, age, salary, (salary * 0.2) as tax from emp_casted

tax = emp_casted.withColumn("tax", col("salary") * 0.2)
tax.show()
# Out:
# +-----------+-------------+---+-------+-------+
# |employee_id|         name|age| salary|    tax|
# +-----------+-------------+---+-------+-------+
# |        001|     John Doe| 30|50000.0|10000.0|
# |        002|   Jane Smith| 25|45000.0| 9000.0|
# |        003|    Bob Brown| 35|55000.0|11000.0|
# |        004|    Alice Lee| 28|48000.0| 9600.0|
# |        005|    Jack Chan| 40|60000.0|12000.0|
# |        006|    Jill Wong| 32|52000.0|10400.0|
# |        007|James Johnson| 42|70000.0|14000.0|
# |        008|     Kate Kim| 29|51000.0|10200.0|
# |        009|      Tom Tan| 33|58000.0|11600.0|
# |        010|     Lisa Lee| 27|47000.0| 9400.0|
# |        011|   David Park| 38|65000.0|13000.0|
# |        012|   Susan Chen| 31|54000.0|10800.0|
# |        013|    Brian Kim| 45|75000.0|15000.0|
# |        014|    Emily Lee| 26|46000.0| 9200.0|
# |        015|  Michael Lee| 37|63000.0|12600.0|
# |        016|  Kelly Zhang| 30|49000.0| 9800.0|
# |        017|  George Wang| 34|57000.0|11400.0|
# |        018|    Nancy Liu| 29|50000.0|10000.0|
# |        019|  Steven Chen| 36|62000.0|12400.0|
# |        020|    Grace Kim| 32|53000.0|10600.0|
# +-----------+-------------+---+-------+-------+

# %%
# Literals
# select employee_id, name, age, salary, tax, 1 as columnOne, 'two' as columnTwo from emp_taxed

from pyspark.sql.functions import lit

emp_new_cols = tax.withColumn("columnOne", lit(1)).withColumn("columnTwo", lit('two')).withColumn("columnThree", lit(1.5) * 2)
emp_new_cols.show()
# Out:
# +-----------+-------------+---+-------+-------+---------+---------+-----------+
# |employee_id|         name|age| salary|    tax|columnOne|columnTwo|columnThree|
# +-----------+-------------+---+-------+-------+---------+---------+-----------+
# |        001|     John Doe| 30|50000.0|10000.0|        1|      two|        3.0|
# |        002|   Jane Smith| 25|45000.0| 9000.0|        1|      two|        3.0|
# |        003|    Bob Brown| 35|55000.0|11000.0|        1|      two|        3.0|
# |        004|    Alice Lee| 28|48000.0| 9600.0|        1|      two|        3.0|
# |        005|    Jack Chan| 40|60000.0|12000.0|        1|      two|        3.0|
# |        006|    Jill Wong| 32|52000.0|10400.0|        1|      two|        3.0|
# |        007|James Johnson| 42|70000.0|14000.0|        1|      two|        3.0|
# |        008|     Kate Kim| 29|51000.0|10200.0|        1|      two|        3.0|
# |        009|      Tom Tan| 33|58000.0|11600.0|        1|      two|        3.0|
# |        010|     Lisa Lee| 27|47000.0| 9400.0|        1|      two|        3.0|
# |        011|   David Park| 38|65000.0|13000.0|        1|      two|        3.0|
# |        012|   Susan Chen| 31|54000.0|10800.0|        1|      two|        3.0|
# |        013|    Brian Kim| 45|75000.0|15000.0|        1|      two|        3.0|
# |        014|    Emily Lee| 26|46000.0| 9200.0|        1|      two|        3.0|
# |        015|  Michael Lee| 37|63000.0|12600.0|        1|      two|        3.0|
# |        016|  Kelly Zhang| 30|49000.0| 9800.0|        1|      two|        3.0|
# |        017|  George Wang| 34|57000.0|11400.0|        1|      two|        3.0|
# |        018|    Nancy Liu| 29|50000.0|10000.0|        1|      two|        3.0|
# |        019|  Steven Chen| 36|62000.0|12400.0|        1|      two|        3.0|
# |        020|    Grace Kim| 32|53000.0|10600.0|        1|      two|        3.0|
# +-----------+-------------+---+-------+-------+---------+---------+-----------+

# %%
# Renaming Columns
# select employee_id as emp_id, name, age, salary, tax, columnOne, columnTwo from emp_new_cols

emp_1 = emp_new_cols.withColumnRenamed("employee_id", "emp_id")
emp_1.show()
emp_1.printSchema()
# Out:
# +------+-------------+---+-------+-------+---------+---------+-----------+
# |emp_id|         name|age| salary|    tax|columnOne|columnTwo|columnThree|
# +------+-------------+---+-------+-------+---------+---------+-----------+
# |   001|     John Doe| 30|50000.0|10000.0|        1|      two|        3.0|
# |   002|   Jane Smith| 25|45000.0| 9000.0|        1|      two|        3.0|
# |   003|    Bob Brown| 35|55000.0|11000.0|        1|      two|        3.0|
# |   004|    Alice Lee| 28|48000.0| 9600.0|        1|      two|        3.0|
# |   005|    Jack Chan| 40|60000.0|12000.0|        1|      two|        3.0|
# |   006|    Jill Wong| 32|52000.0|10400.0|        1|      two|        3.0|
# |   007|James Johnson| 42|70000.0|14000.0|        1|      two|        3.0|
# |   008|     Kate Kim| 29|51000.0|10200.0|        1|      two|        3.0|
# |   009|      Tom Tan| 33|58000.0|11600.0|        1|      two|        3.0|
# |   010|     Lisa Lee| 27|47000.0| 9400.0|        1|      two|        3.0|
# |   011|   David Park| 38|65000.0|13000.0|        1|      two|        3.0|
# |   012|   Susan Chen| 31|54000.0|10800.0|        1|      two|        3.0|
# |   013|    Brian Kim| 45|75000.0|15000.0|        1|      two|        3.0|
# |   014|    Emily Lee| 26|46000.0| 9200.0|        1|      two|        3.0|
# |   015|  Michael Lee| 37|63000.0|12600.0|        1|      two|        3.0|
# |   016|  Kelly Zhang| 30|49000.0| 9800.0|        1|      two|        3.0|
# |   017|  George Wang| 34|57000.0|11400.0|        1|      two|        3.0|
# |   018|    Nancy Liu| 29|50000.0|10000.0|        1|      two|        3.0|
# |   019|  Steven Chen| 36|62000.0|12400.0|        1|      two|        3.0|
# |   020|    Grace Kim| 32|53000.0|10600.0|        1|      two|        3.0|
# +------+-------------+---+-------+-------+---------+---------+-----------+
#
# root
#  |-- emp_id: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- salary: double (nullable = true)
#  |-- tax: double (nullable = true)
#  |-- columnOne: integer (nullable = false)
#  |-- columnTwo: string (nullable = false)
#  |-- columnThree: double (nullable = false)

# %%
# Column names with Spaces
# select employee_id as emp_id, name, age, salary, tax, columnOne, columnTwo as `Column Two` from emp_new_cols

emp_2 = emp_new_cols.withColumnRenamed("columnOne", "Column One").withColumnRenamed("columnTwo", "Column Two")
emp_2.show()
# Out:
# +-----------+-------------+---+-------+-------+----------+----------+-----------+
# |employee_id|         name|age| salary|    tax|Column One|Column Two|columnThree|
# +-----------+-------------+---+-------+-------+----------+----------+-----------+
# |        001|     John Doe| 30|50000.0|10000.0|         1|       two|        3.0|
# |        002|   Jane Smith| 25|45000.0| 9000.0|         1|       two|        3.0|
# |        003|    Bob Brown| 35|55000.0|11000.0|         1|       two|        3.0|
# |        004|    Alice Lee| 28|48000.0| 9600.0|         1|       two|        3.0|
# |        005|    Jack Chan| 40|60000.0|12000.0|         1|       two|        3.0|
# |        006|    Jill Wong| 32|52000.0|10400.0|         1|       two|        3.0|
# |        007|James Johnson| 42|70000.0|14000.0|         1|       two|        3.0|
# |        008|     Kate Kim| 29|51000.0|10200.0|         1|       two|        3.0|
# |        009|      Tom Tan| 33|58000.0|11600.0|         1|       two|        3.0|
# |        010|     Lisa Lee| 27|47000.0| 9400.0|         1|       two|        3.0|
# |        011|   David Park| 38|65000.0|13000.0|         1|       two|        3.0|
# |        012|   Susan Chen| 31|54000.0|10800.0|         1|       two|        3.0|
# |        013|    Brian Kim| 45|75000.0|15000.0|         1|       two|        3.0|
# |        014|    Emily Lee| 26|46000.0| 9200.0|         1|       two|        3.0|
# |        015|  Michael Lee| 37|63000.0|12600.0|         1|       two|        3.0|
# |        016|  Kelly Zhang| 30|49000.0| 9800.0|         1|       two|        3.0|
# |        017|  George Wang| 34|57000.0|11400.0|         1|       two|        3.0|
# |        018|    Nancy Liu| 29|50000.0|10000.0|         1|       two|        3.0|
# |        019|  Steven Chen| 36|62000.0|12400.0|         1|       two|        3.0|
# |        020|    Grace Kim| 32|53000.0|10600.0|         1|       two|        3.0|
# +-----------+-------------+---+-------+-------+----------+----------+-----------+

# %%
# Remove Column

emp_dropped = emp_new_cols.drop("columnThree", "columnTwo", "columnOne")
emp_dropped.show()
# Out:
# +-----------+-------------+---+-------+-------+
# |employee_id|         name|age| salary|    tax|
# +-----------+-------------+---+-------+-------+
# |        001|     John Doe| 30|50000.0|10000.0|
# |        002|   Jane Smith| 25|45000.0| 9000.0|
# |        003|    Bob Brown| 35|55000.0|11000.0|
# |        004|    Alice Lee| 28|48000.0| 9600.0|
# |        005|    Jack Chan| 40|60000.0|12000.0|
# |        006|    Jill Wong| 32|52000.0|10400.0|
# |        007|James Johnson| 42|70000.0|14000.0|
# |        008|     Kate Kim| 29|51000.0|10200.0|
# |        009|      Tom Tan| 33|58000.0|11600.0|
# |        010|     Lisa Lee| 27|47000.0| 9400.0|
# |        011|   David Park| 38|65000.0|13000.0|
# |        012|   Susan Chen| 31|54000.0|10800.0|
# |        013|    Brian Kim| 45|75000.0|15000.0|
# |        014|    Emily Lee| 26|46000.0| 9200.0|
# |        015|  Michael Lee| 37|63000.0|12600.0|
# |        016|  Kelly Zhang| 30|49000.0| 9800.0|
# |        017|  George Wang| 34|57000.0|11400.0|
# |        018|    Nancy Liu| 29|50000.0|10000.0|
# |        019|  Steven Chen| 36|62000.0|12400.0|
# |        020|    Grace Kim| 32|53000.0|10600.0|
# +-----------+-------------+---+-------+-------+

# %%
# Filter data 
# select employee_id as emp_id, name, age, salary, tax, columnOne from emp_col_dropped where tax > 1000

emp_filtered = emp_dropped.where("tax > 10000")
emp_filtered.show()
# Out:
# +-----------+-------------+---+-------+-------+
# |employee_id|         name|age| salary|    tax|
# +-----------+-------------+---+-------+-------+
# |        003|    Bob Brown| 35|55000.0|11000.0|
# |        005|    Jack Chan| 40|60000.0|12000.0|
# |        006|    Jill Wong| 32|52000.0|10400.0|
# |        007|James Johnson| 42|70000.0|14000.0|
# |        008|     Kate Kim| 29|51000.0|10200.0|
# |        009|      Tom Tan| 33|58000.0|11600.0|
# |        011|   David Park| 38|65000.0|13000.0|
# |        012|   Susan Chen| 31|54000.0|10800.0|
# |        013|    Brian Kim| 45|75000.0|15000.0|
# |        015|  Michael Lee| 37|63000.0|12600.0|
# |        017|  George Wang| 34|57000.0|11400.0|
# |        019|  Steven Chen| 36|62000.0|12400.0|
# |        020|    Grace Kim| 32|53000.0|10600.0|
# +-----------+-------------+---+-------+-------+

# %%
# LIMIT data
# select employee_id as emp_id, name, age, salary, tax, columnOne from emp_filtered limit 5

emp_limit = emp_filtered.limit(5)
emp_limit.show()
# Out:
# +-----------+-------------+---+-------+-------+
# |employee_id|         name|age| salary|    tax|
# +-----------+-------------+---+-------+-------+
# |        003|    Bob Brown| 35|55000.0|11000.0|
# |        005|    Jack Chan| 40|60000.0|12000.0|
# |        006|    Jill Wong| 32|52000.0|10400.0|
# |        007|James Johnson| 42|70000.0|14000.0|
# |        008|     Kate Kim| 29|51000.0|10200.0|
# +-----------+-------------+---+-------+-------+

# %%
# Show limited data while viewing

emp_limit.show(2)
# Out:
# +-----------+---------+---+-------+-------+
# |employee_id|     name|age| salary|    tax|
# +-----------+---------+---+-------+-------+
# |        003|Bob Brown| 35|55000.0|11000.0|
# |        005|Jack Chan| 40|60000.0|12000.0|
# +-----------+---------+---+-------+-------+
# only showing top 2 rows

# %%
# Add multiple columns

columns = {
    "tax" : col("salary") * 0.2 ,
    "oneNumber" : lit(1), 
    "columnTwo" : lit("two")
}

emp_final = emp.withColumns(columns)
emp_final.show()
# Out:
# +-----------+-------------+-------------+---+------+------+----------+-------+---------+---------+
# |employee_id|department_id|         name|age|gender|salary| hire_date|    tax|oneNumber|columnTwo|
# +-----------+-------------+-------------+---+------+------+----------+-------+---------+---------+
# |        001|          101|     John Doe| 30|  Male| 50000|2015-01-01|10000.0|        1|      two|
# |        002|          101|   Jane Smith| 25|Female| 45000|2016-02-15| 9000.0|        1|      two|
# |        003|          102|    Bob Brown| 35|  Male| 55000|2014-05-01|11000.0|        1|      two|
# |        004|          102|    Alice Lee| 28|Female| 48000|2017-09-30| 9600.0|        1|      two|
# |        005|          103|    Jack Chan| 40|  Male| 60000|2013-04-01|12000.0|        1|      two|
# |        006|          103|    Jill Wong| 32|Female| 52000|2018-07-01|10400.0|        1|      two|
# |        007|          101|James Johnson| 42|  Male| 70000|2012-03-15|14000.0|        1|      two|
# |        008|          102|     Kate Kim| 29|Female| 51000|2019-10-01|10200.0|        1|      two|
# |        009|          103|      Tom Tan| 33|  Male| 58000|2016-06-01|11600.0|        1|      two|
# |        010|          104|     Lisa Lee| 27|Female| 47000|2018-08-01| 9400.0|        1|      two|
# |        011|          104|   David Park| 38|  Male| 65000|2015-11-01|13000.0|        1|      two|
# |        012|          105|   Susan Chen| 31|Female| 54000|2017-02-15|10800.0|        1|      two|
# |        013|          106|    Brian Kim| 45|  Male| 75000|2011-07-01|15000.0|        1|      two|
# |        014|          107|    Emily Lee| 26|Female| 46000|2019-01-01| 9200.0|        1|      two|
# |        015|          106|  Michael Lee| 37|  Male| 63000|2014-09-30|12600.0|        1|      two|
# |        016|          107|  Kelly Zhang| 30|Female| 49000|2018-04-01| 9800.0|        1|      two|
# |        017|          105|  George Wang| 34|  Male| 57000|2016-03-15|11400.0|        1|      two|
# |        018|          104|    Nancy Liu| 29|Female| 50000|2017-06-01|10000.0|        1|      two|
# |        019|          103|  Steven Chen| 36|  Male| 62000|2015-08-01|12400.0|        1|      two|
# |        020|          102|    Grace Kim| 32|Female| 53000|2018-11-01|10600.0|        1|      two|
# +-----------+-------------+-------------+---+------+------+----------+-------+---------+---------+

# %%
# Write data as CSV
emp_final.write.format("csv").save("data/output/03/emp.csv")
