# %%
# Spark Session

from pyspark.sql import SparkSession

spark = (
    SparkSession
    .builder
    .appName("Working with Strings & Dates")
    .master("local[*]")
    .getOrCreate()
)

spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://7cd61605f34d:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Working with Strings & Dates</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# Emp Data & Schema

emp_data = [
    ["001","101","John Doe","30","Male","50000","2015-01-01"],
    ["002","101","Jane Smith","25","Female","45000","2016-02-15"],
    ["003","102","Bob Brown","35","Male","55000","2014-05-01"],
    ["004","102","Alice Lee","28","Female","48000","2017-09-30"],
    ["005","103","Jack Chan","40","Male","60000","2013-04-01"],
    ["006","103","Jill Wong","32","Female","52000","2018-07-01"],
    ["007","101","James Johnson","42","Male","70000","2012-03-15"],
    ["008","102","Kate Kim","29","Female","51000","2019-10-01"],
    ["009","103","Tom Tan","33","Male","58000","2016-06-01"],
    ["010","104","Lisa Lee","27","Female","47000","2018-08-01"],
    ["011","104","David Park","38","Male","65000","2015-11-01"],
    ["012","105","Susan Chen","31","Female","54000","2017-02-15"],
    ["013","106","Brian Kim","45","Male","75000","2011-07-01"],
    ["014","107","Emily Lee","26","Female","46000","2019-01-01"],
    ["015","106","Michael Lee","37","Male","63000","2014-09-30"],
    ["016","107","Kelly Zhang","30","Female","49000","2018-04-01"],
    ["017","105","George Wang","34","Male","57000","2016-03-15"],
    ["018","104","Nancy Liu","29","","50000","2017-06-01"],
    ["019","103","Steven Chen","36","Male","62000","2015-08-01"],
    ["020","102","Grace Kim","32","Female","53000","2018-11-01"]
]

emp_schema = "employee_id string, department_id string, name string, age string, gender string, salary string, hire_date string"

# %%
# Create emp DataFrame

emp = spark.createDataFrame(data=emp_data, schema=emp_schema)

# Show emp dataframe (ACTION)

emp.show()
# Out:
# +-----------+-------------+-------------+---+------+------+----------+
# |employee_id|department_id|         name|age|gender|salary| hire_date|
# +-----------+-------------+-------------+---+------+------+----------+
# |        001|          101|     John Doe| 30|  Male| 50000|2015-01-01|
# |        002|          101|   Jane Smith| 25|Female| 45000|2016-02-15|
# |        003|          102|    Bob Brown| 35|  Male| 55000|2014-05-01|
# |        004|          102|    Alice Lee| 28|Female| 48000|2017-09-30|
# |        005|          103|    Jack Chan| 40|  Male| 60000|2013-04-01|
# |        006|          103|    Jill Wong| 32|Female| 52000|2018-07-01|
# |        007|          101|James Johnson| 42|  Male| 70000|2012-03-15|
# |        008|          102|     Kate Kim| 29|Female| 51000|2019-10-01|
# |        009|          103|      Tom Tan| 33|  Male| 58000|2016-06-01|
# |        010|          104|     Lisa Lee| 27|Female| 47000|2018-08-01|
# |        011|          104|   David Park| 38|  Male| 65000|2015-11-01|
# |        012|          105|   Susan Chen| 31|Female| 54000|2017-02-15|
# |        013|          106|    Brian Kim| 45|  Male| 75000|2011-07-01|
# |        014|          107|    Emily Lee| 26|Female| 46000|2019-01-01|
# |        015|          106|  Michael Lee| 37|  Male| 63000|2014-09-30|
# |        016|          107|  Kelly Zhang| 30|Female| 49000|2018-04-01|
# |        017|          105|  George Wang| 34|  Male| 57000|2016-03-15|
# |        018|          104|    Nancy Liu| 29|      | 50000|2017-06-01|
# |        019|          103|  Steven Chen| 36|  Male| 62000|2015-08-01|
# |        020|          102|    Grace Kim| 32|Female| 53000|2018-11-01|
# +-----------+-------------+-------------+---+------+------+----------+

# %%
emp.printSchema()
# Out:
# root
#  |-- employee_id: string (nullable = true)
#  |-- department_id: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- age: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- salary: string (nullable = true)
#  |-- hire_date: string (nullable = true)

# %%
# Case When
# select employee_id, name, age, salary, gender,
# case when gender = 'Male' then 'M' when gender = 'Female' then 'F' else null end as new_gender, hire_date from emp

from pyspark.sql.functions import col, expr, when

emp_gender_fixed = emp.withColumn("new_gender", when(col("gender") == 'Male', 'M')
                                 .when(col("gender") == 'Female', 'F')
                                 .otherwise(None)
                                 )
emp_gndr = emp.withColumn("new_gndr", when(col("gender") == 'Male', 'M')
                         .when(col("gender") == 'Female', 'F')
                         .otherwise(None))
                            
emp_gender_fixed_1 = emp.withColumn("new_gender", expr("case when gender = 'Male' then 'M' when gender = 'Female' then 'F' else null end"))
emp_gndr_expr = emp.withColumn("new_gender", expr("case when gender = 'Male' then 'M' when gender = 'Female' then 'F' else null end"))

# %%
emp_gender_fixed.show()
emp_gender_fixed_1.show()
# Out:
# +-----------+-------------+-------------+---+------+------+----------+----------+
# |employee_id|department_id|         name|age|gender|salary| hire_date|new_gender|
# +-----------+-------------+-------------+---+------+------+----------+----------+
# |        001|          101|     John Doe| 30|  Male| 50000|2015-01-01|         M|
# |        002|          101|   Jane Smith| 25|Female| 45000|2016-02-15|         F|
# |        003|          102|    Bob Brown| 35|  Male| 55000|2014-05-01|         M|
# |        004|          102|    Alice Lee| 28|Female| 48000|2017-09-30|         F|
# |        005|          103|    Jack Chan| 40|  Male| 60000|2013-04-01|         M|
# |        006|          103|    Jill Wong| 32|Female| 52000|2018-07-01|         F|
# |        007|          101|James Johnson| 42|  Male| 70000|2012-03-15|         M|
# |        008|          102|     Kate Kim| 29|Female| 51000|2019-10-01|         F|
# |        009|          103|      Tom Tan| 33|  Male| 58000|2016-06-01|         M|
# |        010|          104|     Lisa Lee| 27|Female| 47000|2018-08-01|         F|
# |        011|          104|   David Park| 38|  Male| 65000|2015-11-01|         M|
# |        012|          105|   Susan Chen| 31|Female| 54000|2017-02-15|         F|
# |        013|          106|    Brian Kim| 45|  Male| 75000|2011-07-01|         M|
# |        014|          107|    Emily Lee| 26|Female| 46000|2019-01-01|         F|
# |        015|          106|  Michael Lee| 37|  Male| 63000|2014-09-30|         M|
# |        016|          107|  Kelly Zhang| 30|Female| 49000|2018-04-01|         F|
# |        017|          105|  George Wang| 34|  Male| 57000|2016-03-15|         M|
# |        018|          104|    Nancy Liu| 29|      | 50000|2017-06-01|      null|
# |        019|          103|  Steven Chen| 36|  Male| 62000|2015-08-01|         M|
# |        020|          102|    Grace Kim| 32|Female| 53000|2018-11-01|         F|
# +-----------+-------------+-------------+---+------+------+----------+----------+
#
# +-----------+-------------+-------------+---+------+------+----------+----------+
# |employee_id|department_id|         name|age|gender|salary| hire_date|new_gender|
# +-----------+-------------+-------------+---+------+------+----------+----------+
# |        001|          101|     John Doe| 30|  Male| 50000|2015-01-01|         M|
# |        002|          101|   Jane Smith| 25|Female| 45000|2016-02-15|         F|
# |        003|          102|    Bob Brown| 35|  Male| 55000|2014-05-01|         M|
# |        004|          102|    Alice Lee| 28|Female| 48000|2017-09-30|         F|
# |        005|          103|    Jack Chan| 40|  Male| 60000|2013-04-01|         M|
# |        006|          103|    Jill Wong| 32|Female| 52000|2018-07-01|         F|
# |        007|          101|James Johnson| 42|  Male| 70000|2012-03-15|         M|
# |        008|          102|     Kate Kim| 29|Female| 51000|2019-10-01|         F|
# |        009|          103|      Tom Tan| 33|  Male| 58000|2016-06-01|         M|
# |        010|          104|     Lisa Lee| 27|Female| 47000|2018-08-01|         F|
# |        011|          104|   David Park| 38|  Male| 65000|2015-11-01|         M|
# |        012|          105|   Susan Chen| 31|Female| 54000|2017-02-15|         F|
# |        013|          106|    Brian Kim| 45|  Male| 75000|2011-07-01|         M|
# |        014|          107|    Emily Lee| 26|Female| 46000|2019-01-01|         F|
# |        015|          106|  Michael Lee| 37|  Male| 63000|2014-09-30|         M|
# |        016|          107|  Kelly Zhang| 30|Female| 49000|2018-04-01|         F|
# |        017|          105|  George Wang| 34|  Male| 57000|2016-03-15|         M|
# |        018|          104|    Nancy Liu| 29|      | 50000|2017-06-01|      null|
# |        019|          103|  Steven Chen| 36|  Male| 62000|2015-08-01|         M|
# |        020|          102|    Grace Kim| 32|Female| 53000|2018-11-01|         F|
# +-----------+-------------+-------------+---+------+------+----------+----------+

# %%
# Replace in Strings
# select employee_id, name, replace(name, 'J', 'Z') as new_name, age, salary, gender, new_gender, hire_date from emp_gender_fixed

from pyspark.sql.functions import regexp_replace

emp_name = emp.withColumn("new_name", regexp_replace(col("name"), "J", "Z"))

# %%
emp_name.show()
# Out:
# +-----------+-------------+-------------+---+------+------+----------+-------------+
# |employee_id|department_id|         name|age|gender|salary| hire_date|     new_name|
# +-----------+-------------+-------------+---+------+------+----------+-------------+
# |        001|          101|     John Doe| 30|  Male| 50000|2015-01-01|     Zohn Doe|
# |        002|          101|   Jane Smith| 25|Female| 45000|2016-02-15|   Zane Smith|
# |        003|          102|    Bob Brown| 35|  Male| 55000|2014-05-01|    Bob Brown|
# |        004|          102|    Alice Lee| 28|Female| 48000|2017-09-30|    Alice Lee|
# |        005|          103|    Jack Chan| 40|  Male| 60000|2013-04-01|    Zack Chan|
# |        006|          103|    Jill Wong| 32|Female| 52000|2018-07-01|    Zill Wong|
# |        007|          101|James Johnson| 42|  Male| 70000|2012-03-15|Zames Zohnson|
# |        008|          102|     Kate Kim| 29|Female| 51000|2019-10-01|     Kate Kim|
# |        009|          103|      Tom Tan| 33|  Male| 58000|2016-06-01|      Tom Tan|
# |        010|          104|     Lisa Lee| 27|Female| 47000|2018-08-01|     Lisa Lee|
# |        011|          104|   David Park| 38|  Male| 65000|2015-11-01|   David Park|
# |        012|          105|   Susan Chen| 31|Female| 54000|2017-02-15|   Susan Chen|
# |        013|          106|    Brian Kim| 45|  Male| 75000|2011-07-01|    Brian Kim|
# |        014|          107|    Emily Lee| 26|Female| 46000|2019-01-01|    Emily Lee|
# |        015|          106|  Michael Lee| 37|  Male| 63000|2014-09-30|  Michael Lee|
# |        016|          107|  Kelly Zhang| 30|Female| 49000|2018-04-01|  Kelly Zhang|
# |        017|          105|  George Wang| 34|  Male| 57000|2016-03-15|  George Wang|
# |        018|          104|    Nancy Liu| 29|      | 50000|2017-06-01|    Nancy Liu|
# |        019|          103|  Steven Chen| 36|  Male| 62000|2015-08-01|  Steven Chen|
# |        020|          102|    Grace Kim| 32|Female| 53000|2018-11-01|    Grace Kim|
# +-----------+-------------+-------------+---+------+------+----------+-------------+

# %%
emp_name.printSchema()
# Out:
# root
#  |-- employee_id: string (nullable = true)
#  |-- department_id: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- age: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- salary: string (nullable = true)
#  |-- hire_date: string (nullable = true)
#  |-- new_name: string (nullable = true)

# %%
# Convert Date
# select *,  to_date(hire_date, 'YYYY-MM-DD') as hire_date from emp_name_fixed
from pyspark.sql.functions import to_date

emp_date_fix = emp_name.withColumn("hire_date", to_date(col("hire_date"), 'yyyy-MM-dd'))
emp_date_fix.printSchema()
emp_date_fix.show()
# Out:
# root
#  |-- employee_id: string (nullable = true)
#  |-- department_id: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- age: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- salary: string (nullable = true)
#  |-- hire_date: date (nullable = true)
#  |-- new_name: string (nullable = true)
#
# +-----------+-------------+-------------+---+------+------+----------+-------------+
# |employee_id|department_id|         name|age|gender|salary| hire_date|     new_name|
# +-----------+-------------+-------------+---+------+------+----------+-------------+
# |        001|          101|     John Doe| 30|  Male| 50000|2015-01-01|     Zohn Doe|
# |        002|          101|   Jane Smith| 25|Female| 45000|2016-02-15|   Zane Smith|
# |        003|          102|    Bob Brown| 35|  Male| 55000|2014-05-01|    Bob Brown|
# |        004|          102|    Alice Lee| 28|Female| 48000|2017-09-30|    Alice Lee|
# |        005|          103|    Jack Chan| 40|  Male| 60000|2013-04-01|    Zack Chan|
# |        006|          103|    Jill Wong| 32|Female| 52000|2018-07-01|    Zill Wong|
# |        007|          101|James Johnson| 42|  Male| 70000|2012-03-15|Zames Zohnson|
# |        008|          102|     Kate Kim| 29|Female| 51000|2019-10-01|     Kate Kim|
# |        009|          103|      Tom Tan| 33|  Male| 58000|2016-06-01|      Tom Tan|
# |        010|          104|     Lisa Lee| 27|Female| 47000|2018-08-01|     Lisa Lee|
# |        011|          104|   David Park| 38|  Male| 65000|2015-11-01|   David Park|
# |        012|          105|   Susan Chen| 31|Female| 54000|2017-02-15|   Susan Chen|
# |        013|          106|    Brian Kim| 45|  Male| 75000|2011-07-01|    Brian Kim|
# |        014|          107|    Emily Lee| 26|Female| 46000|2019-01-01|    Emily Lee|
# |        015|          106|  Michael Lee| 37|  Male| 63000|2014-09-30|  Michael Lee|
# |        016|          107|  Kelly Zhang| 30|Female| 49000|2018-04-01|  Kelly Zhang|
# |        017|          105|  George Wang| 34|  Male| 57000|2016-03-15|  George Wang|
# |        018|          104|    Nancy Liu| 29|      | 50000|2017-06-01|    Nancy Liu|
# |        019|          103|  Steven Chen| 36|  Male| 62000|2015-08-01|  Steven Chen|
# |        020|          102|    Grace Kim| 32|Female| 53000|2018-11-01|    Grace Kim|
# +-----------+-------------+-------------+---+------+------+----------+-------------+

# %%
# Add Date Columns
# Add current_date, current_timestamp, extract year from hire_date
from pyspark.sql.functions import current_date, current_timestamp

emp_dated = emp_date_fix.withColumn("date_now", current_date()).withColumn("timestamp_now", current_timestamp())
emp_dated.show()
emp_dated.show(truncate=False)  # shows full table without wrapping texts
# Out:
# +-----------+-------------+-------------+---+------+------+----------+-------------+----------+--------------------+
# |employee_id|department_id|         name|age|gender|salary| hire_date|     new_name|  date_now|       timestamp_now|
# +-----------+-------------+-------------+---+------+------+----------+-------------+----------+--------------------+
# |        001|          101|     John Doe| 30|  Male| 50000|2015-01-01|     Zohn Doe|2026-03-19|2026-03-19 19:46:...|
# |        002|          101|   Jane Smith| 25|Female| 45000|2016-02-15|   Zane Smith|2026-03-19|2026-03-19 19:46:...|
# |        003|          102|    Bob Brown| 35|  Male| 55000|2014-05-01|    Bob Brown|2026-03-19|2026-03-19 19:46:...|
# |        004|          102|    Alice Lee| 28|Female| 48000|2017-09-30|    Alice Lee|2026-03-19|2026-03-19 19:46:...|
# |        005|          103|    Jack Chan| 40|  Male| 60000|2013-04-01|    Zack Chan|2026-03-19|2026-03-19 19:46:...|
# |        006|          103|    Jill Wong| 32|Female| 52000|2018-07-01|    Zill Wong|2026-03-19|2026-03-19 19:46:...|
# |        007|          101|James Johnson| 42|  Male| 70000|2012-03-15|Zames Zohnson|2026-03-19|2026-03-19 19:46:...|
# |        008|          102|     Kate Kim| 29|Female| 51000|2019-10-01|     Kate Kim|2026-03-19|2026-03-19 19:46:...|
# |        009|          103|      Tom Tan| 33|  Male| 58000|2016-06-01|      Tom Tan|2026-03-19|2026-03-19 19:46:...|
# |        010|          104|     Lisa Lee| 27|Female| 47000|2018-08-01|     Lisa Lee|2026-03-19|2026-03-19 19:46:...|
# |        011|          104|   David Park| 38|  Male| 65000|2015-11-01|   David Park|2026-03-19|2026-03-19 19:46:...|
# |        012|          105|   Susan Chen| 31|Female| 54000|2017-02-15|   Susan Chen|2026-03-19|2026-03-19 19:46:...|
# |        013|          106|    Brian Kim| 45|  Male| 75000|2011-07-01|    Brian Kim|2026-03-19|2026-03-19 19:46:...|
# |        014|          107|    Emily Lee| 26|Female| 46000|2019-01-01|    Emily Lee|2026-03-19|2026-03-19 19:46:...|
# |        015|          106|  Michael Lee| 37|  Male| 63000|2014-09-30|  Michael Lee|2026-03-19|2026-03-19 19:46:...|
# |        018|          104|    Nancy Liu| 29|      | 50000|2017-06-01|    Nancy Liu|2026-03-19|2026-03-19 19:46:...|
# |        019|          103|  Steven Chen| 36|  Male| 62000|2015-08-01|  Steven Chen|2026-03-19|2026-03-19 19:46:...|
# |        020|          102|    Grace Kim| 32|Female| 53000|2018-11-01|    Grace Kim|2026-03-19|2026-03-19 19:46:...|
# +-----------+-------------+-------------+---+------+------+----------+-------------+----------+--------------------+

# %%
# Fix Null values
# select *, nvl('new_gender', 'O') as new_gender from emp_dated
from pyspark.sql.functions import coalesce, lit

emp_null_df = emp_dated.withColumn("new_gender", coalesce(col("gender"), lit("O")))
emp_null_df.show()
# Out:
# +-----------+-------------+-------------+---+------+------+----------+-------------+----------+--------------------+----------+
# |employee_id|department_id|         name|age|gender|salary| hire_date|     new_name|  date_now|       timestamp_now|new_gender|
# +-----------+-------------+-------------+---+------+------+----------+-------------+----------+--------------------+----------+
# |        001|          101|     John Doe| 30|  Male| 50000|2015-01-01|     Zohn Doe|2026-03-19|2026-03-19 19:55:...|      Male|
# |        002|          101|   Jane Smith| 25|Female| 45000|2016-02-15|   Zane Smith|2026-03-19|2026-03-19 19:55:...|    Female|
# |        003|          102|    Bob Brown| 35|  Male| 55000|2014-05-01|    Bob Brown|2026-03-19|2026-03-19 19:55:...|      Male|
# |        004|          102|    Alice Lee| 28|Female| 48000|2017-09-30|    Alice Lee|2026-03-19|2026-03-19 19:55:...|    Female|
# |        005|          103|    Jack Chan| 40|  Male| 60000|2013-04-01|    Zack Chan|2026-03-19|2026-03-19 19:55:...|      Male|
# |        006|          103|    Jill Wong| 32|Female| 52000|2018-07-01|    Zill Wong|2026-03-19|2026-03-19 19:55:...|    Female|
# |        007|          101|James Johnson| 42|  Male| 70000|2012-03-15|Zames Zohnson|2026-03-19|2026-03-19 19:55:...|      Male|
# |        008|          102|     Kate Kim| 29|Female| 51000|2019-10-01|     Kate Kim|2026-03-19|2026-03-19 19:55:...|    Female|
# |        009|          103|      Tom Tan| 33|  Male| 58000|2016-06-01|      Tom Tan|2026-03-19|2026-03-19 19:55:...|      Male|
# |        010|          104|     Lisa Lee| 27|Female| 47000|2018-08-01|     Lisa Lee|2026-03-19|2026-03-19 19:55:...|    Female|
# |        011|          104|   David Park| 38|  Male| 65000|2015-11-01|   David Park|2026-03-19|2026-03-19 19:55:...|      Male|
# |        012|          105|   Susan Chen| 31|Female| 54000|2017-02-15|   Susan Chen|2026-03-19|2026-03-19 19:55:...|    Female|
# |        013|          106|    Brian Kim| 45|  Male| 75000|2011-07-01|    Brian Kim|2026-03-19|2026-03-19 19:55:...|      Male|
# |        014|          107|    Emily Lee| 26|Female| 46000|2019-01-01|    Emily Lee|2026-03-19|2026-03-19 19:55:...|    Female|
# |        015|          106|  Michael Lee| 37|  Male| 63000|2014-09-30|  Michael Lee|2026-03-19|2026-03-19 19:55:...|      Male|
# |        016|          107|  Kelly Zhang| 30|Female| 49000|2018-04-01|  Kelly Zhang|2026-03-19|2026-03-19 19:55:...|    Female|
# |        017|          105|  George Wang| 34|  Male| 57000|2016-03-15|  George Wang|2026-03-19|2026-03-19 19:55:...|      Male|
# |        018|          104|    Nancy Liu| 29|      | 50000|2017-06-01|    Nancy Liu|2026-03-19|2026-03-19 19:55:...|          |
# |        019|          103|  Steven Chen| 36|  Male| 62000|2015-08-01|  Steven Chen|2026-03-19|2026-03-19 19:55:...|      Male|
# |        020|          102|    Grace Kim| 32|Female| 53000|2018-11-01|    Grace Kim|2026-03-19|2026-03-19 19:55:...|    Female|
# +-----------+-------------+-------------+---+------+------+----------+-------------+----------+--------------------+----------+

# %%
# Drop old columns and Fix new column names
emp_final = emp_null_df.drop("name", "gender").withColumnRenamed("new_name", "name").withColumnRenamed("new_gender", "gender")
emp_final.show()
# Out:
# +-----------+-------------+---+------+----------+-------------+----------+--------------------+------+
# |employee_id|department_id|age|salary| hire_date|         name|  date_now|       timestamp_now|gender|
# +-----------+-------------+---+------+----------+-------------+----------+--------------------+------+
# |        001|          101| 30| 50000|2015-01-01|     Zohn Doe|2026-03-19|2026-03-19 21:03:...|  Male|
# |        002|          101| 25| 45000|2016-02-15|   Zane Smith|2026-03-19|2026-03-19 21:03:...|Female|
# |        003|          102| 35| 55000|2014-05-01|    Bob Brown|2026-03-19|2026-03-19 21:03:...|  Male|
# |        004|          102| 28| 48000|2017-09-30|    Alice Lee|2026-03-19|2026-03-19 21:03:...|Female|
# |        005|          103| 40| 60000|2013-04-01|    Zack Chan|2026-03-19|2026-03-19 21:03:...|  Male|
# |        006|          103| 32| 52000|2018-07-01|    Zill Wong|2026-03-19|2026-03-19 21:03:...|Female|
# |        007|          101| 42| 70000|2012-03-15|Zames Zohnson|2026-03-19|2026-03-19 21:03:...|  Male|
# |        008|          102| 29| 51000|2019-10-01|     Kate Kim|2026-03-19|2026-03-19 21:03:...|Female|
# |        009|          103| 33| 58000|2016-06-01|      Tom Tan|2026-03-19|2026-03-19 21:03:...|  Male|
# |        010|          104| 27| 47000|2018-08-01|     Lisa Lee|2026-03-19|2026-03-19 21:03:...|Female|
# |        011|          104| 38| 65000|2015-11-01|   David Park|2026-03-19|2026-03-19 21:03:...|  Male|
# |        012|          105| 31| 54000|2017-02-15|   Susan Chen|2026-03-19|2026-03-19 21:03:...|Female|
# |        013|          106| 45| 75000|2011-07-01|    Brian Kim|2026-03-19|2026-03-19 21:03:...|  Male|
# |        014|          107| 26| 46000|2019-01-01|    Emily Lee|2026-03-19|2026-03-19 21:03:...|Female|
# |        015|          106| 37| 63000|2014-09-30|  Michael Lee|2026-03-19|2026-03-19 21:03:...|  Male|
# |        016|          107| 30| 49000|2018-04-01|  Kelly Zhang|2026-03-19|2026-03-19 21:03:...|Female|
# |        017|          105| 34| 57000|2016-03-15|  George Wang|2026-03-19|2026-03-19 21:03:...|  Male|
# |        018|          104| 29| 50000|2017-06-01|    Nancy Liu|2026-03-19|2026-03-19 21:03:...|      |
# |        019|          103| 36| 62000|2015-08-01|  Steven Chen|2026-03-19|2026-03-19 21:03:...|  Male|
# |        020|          102| 32| 53000|2018-11-01|    Grace Kim|2026-03-19|2026-03-19 21:03:...|Female|
# +-----------+-------------+---+------+----------+-------------+----------+--------------------+------+

# %%
# Write data as CSV

emp_final.write.format("csv").save("data/output/04/emp.csv")

# %%
# Convert date into String and extract date information
from pyspark.sql.functions import date_format

emp_fixed = emp_final.withColumn("date_zone", date_format(col("timestamp_now"), "z"))
emp_fixed.show()
# Out:
# +-----------+-------------+---+------+----------+-------------+----------+--------------------+------+---------+
# |employee_id|department_id|age|salary| hire_date|         name|  date_now|       timestamp_now|gender|date_zone|
# +-----------+-------------+---+------+----------+-------------+----------+--------------------+------+---------+
# |        001|          101| 30| 50000|2015-01-01|     Zohn Doe|2026-03-19|2026-03-19 21:24:...|  Male|      UTC|
# |        002|          101| 25| 45000|2016-02-15|   Zane Smith|2026-03-19|2026-03-19 21:24:...|Female|      UTC|
# |        003|          102| 35| 55000|2014-05-01|    Bob Brown|2026-03-19|2026-03-19 21:24:...|  Male|      UTC|
# |        004|          102| 28| 48000|2017-09-30|    Alice Lee|2026-03-19|2026-03-19 21:24:...|Female|      UTC|
# |        005|          103| 40| 60000|2013-04-01|    Zack Chan|2026-03-19|2026-03-19 21:24:...|  Male|      UTC|
# |        006|          103| 32| 52000|2018-07-01|    Zill Wong|2026-03-19|2026-03-19 21:24:...|Female|      UTC|
# |        007|          101| 42| 70000|2012-03-15|Zames Zohnson|2026-03-19|2026-03-19 21:24:...|  Male|      UTC|
# |        008|          102| 29| 51000|2019-10-01|     Kate Kim|2026-03-19|2026-03-19 21:24:...|Female|      UTC|
# |        009|          103| 33| 58000|2016-06-01|      Tom Tan|2026-03-19|2026-03-19 21:24:...|  Male|      UTC|
# |        010|          104| 27| 47000|2018-08-01|     Lisa Lee|2026-03-19|2026-03-19 21:24:...|Female|      UTC|
# |        011|          104| 38| 65000|2015-11-01|   David Park|2026-03-19|2026-03-19 21:24:...|  Male|      UTC|
# |        012|          105| 31| 54000|2017-02-15|   Susan Chen|2026-03-19|2026-03-19 21:24:...|Female|      UTC|
# |        013|          106| 45| 75000|2011-07-01|    Brian Kim|2026-03-19|2026-03-19 21:24:...|  Male|      UTC|
# |        014|          107| 26| 46000|2019-01-01|    Emily Lee|2026-03-19|2026-03-19 21:24:...|Female|      UTC|
# |        015|          106| 37| 63000|2014-09-30|  Michael Lee|2026-03-19|2026-03-19 21:24:...|  Male|      UTC|
# |        016|          107| 30| 49000|2018-04-01|  Kelly Zhang|2026-03-19|2026-03-19 21:24:...|Female|      UTC|
# |        017|          105| 34| 57000|2016-03-15|  George Wang|2026-03-19|2026-03-19 21:24:...|  Male|      UTC|
# |        018|          104| 29| 50000|2017-06-01|    Nancy Liu|2026-03-19|2026-03-19 21:24:...|      |      UTC|
